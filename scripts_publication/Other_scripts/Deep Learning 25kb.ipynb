# %%
# Import
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
import pandas as pd
import numpy as np
from random import sample
# Out:
# 2023-08-15 00:47:25.095252: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# KRONOS DATA
HeLa_1_df  = pd.read_csv ('HeLa_1_scMatrix.tsv.gz', sep='\t')
HeLa_2_df  = pd.read_csv ('HeLa_2_scMatrix.tsv.gz', sep='\t')
JEFF_1_df  = pd.read_csv ('JEFF_1_scMatrix.tsv.gz', sep='\t')
JEFF_2_df  = pd.read_csv ('JEFF_2_scMatrix.tsv.gz', sep='\t')
MCF7_First_df  = pd.read_csv ('MCF7_unsorted_scMatrix.tsv.gz', sep='\t')
MCF7_Normal_df  = pd.read_csv ('MCF7_Normal_scMatrix.tsv.gz', sep='\t')

# MASSEYKOREN DATA
GM12878_G1_library1_replicate1_df  = pd.read_csv ('GM12878-G1_scMatrix.tsv.gz', sep='\t')
GM12878_G2_library1_replicate1_df  = pd.read_csv ('GM12878-G2_scMatrix.tsv.gz', sep='\t')
GM12878_S_library1_replicate1_df  = pd.read_csv ('GM12878-S_scMatrix.tsv.gz', sep='\t')
GM12878_earlyS_library1_replicate1_df  = pd.read_csv ('GM12878-earlyS_scMatrix.tsv.gz', sep='\t')
GM12878_lateS_library1_replicate1_df  = pd.read_csv ('GM12878-lateS_scMatrix.tsv.gz', sep='\t')

# DU DATA
HCT116_DKO1_G1_df  = pd.read_csv ('HCT116_DKO1_scRepli-Seq_G1_scMatrix.tsv.gz', sep='\t')
HCT116_DKO1_S_df  = pd.read_csv ('HCT116_DKO1_scRepli-Seq_S_scMatrix.tsv.gz', sep='\t')
HCT116_WT_G1_df  = pd.read_csv ('HCT116_WT_scRepli-Seq_G1_scMatrix.tsv.gz', sep='\t')
HCT116_WT_S_df  = pd.read_csv ('HCT116_WT_scRepli-Seq_S_scMatrix.tsv.gz', sep='\t')

# Takahashi DATA
Takahashi_df = pd.read_csv ('Takahashi19_scMatrix.tsv.gz', sep='\t')

# %%
JEFF_1_df.head()
# Out:
#                            Cell  chr1:875000-900000  chr1:900000-925000  \
# 0  AAACCTGAGATACACA-1_Hela1.bam                   2                   2
# 1  AAACCTGAGTAGATCA-1_Hela1.bam                   2                   2
# 2  AAACCTGCAAACTCAC-1_Hela1.bam                   2                   2
# 3  AAACCTGTCATCGCAA-1_Hela1.bam                   1                   1
# 4  AAACGGGAGTCAAGGC-1_Hela1.bam                   1                   1
#
#    chr1:925000-950000  chr1:950000-975000  chr1:975000-1000000  \
# 0                   2                   2                    2
# 1                   2                   2                    2
# 2                   2                   2                    2
# 3                   1                   1                    1
# 4                   1                   1                    1
#
#    chr1:1000000-1025000  chr1:1025000-1050000  chr1:1050000-1075000  \
# 0                     2                     2                     2
# 1                     2                     2                     2
# 2                     2                     2                     2
# 3                     1                     1                     1
# 4                     1                     1                     1
#
#    chr1:1075000-1100000  ...  chrY:26375000-26400000  chrY:26400000-26425000  \
# 0                     2  ...                       1                       1
# 1                     2  ...                       1                       1
# 2                     2  ...                       1                       1
# 3                     1  ...                       1                       1
# 4                     1  ...                       1                       1
#
#    chrY:26425000-26450000  chrY:26450000-26475000  chrY:26475000-26500000  \
# 0                       1                       1                       1
# 1                       1                       1                       1
# 2                       1                       1                       1
# 3                       1                       1                       1
# 4                       1                       1                       1
#
#    chrY:26500000-26525000  chrY:26525000-26550000  chrY:26550000-26575000  \
# 0                       1                       1                       1
# 1                       1                       1                       1
# 2                       1                       1                       1
# 3                       1                       1                       2
# 4                       1                       1                       1
#
#    chrY:26575000-26600000  chrY:26600000-26625000
# 0                       1                       1
# 1                       1                       1
# 2                       1                       1
# 3                       2                       2
# 4                       1                       1
#
# [5 rows x 118730 columns]

# %%
KRONOS = pd.concat([HeLa_1_df,HeLa_2_df,JEFF_1_df,JEFF_2_df,MCF7_First_df,MCF7_Normal_df], ignore_index=True)
MK = pd.concat([GM12878_G1_library1_replicate1_df,GM12878_G2_library1_replicate1_df,GM12878_S_library1_replicate1_df,GM12878_earlyS_library1_replicate1_df,GM12878_lateS_library1_replicate1_df], ignore_index=True)
DU = pd.concat([HCT116_DKO1_G1_df,HCT116_DKO1_S_df,HCT116_WT_G1_df,HCT116_WT_S_df], ignore_index=True)
CNV_df = pd.concat([KRONOS,MK,DU,Takahashi_df], ignore_index=True)
#remove X/Y chr
CNV_df = CNV_df[CNV_df.columns.drop(list(CNV_df.filter(regex='chrX:')))]
CNV_df = CNV_df[CNV_df.columns.drop(list(CNV_df.filter(regex='chrY:')))]

CNV_df.head()
# Out:
#                            Cell  chr1:875000-900000  chr1:900000-925000  \
# 0  AAACCTGAGGAGCGTT-1_Jeff1.bam                   3                   3
# 1  AAACCTGCAGTTTGCA-1_Jeff1.bam                   3                   3
# 2  AAACCTGGTCTCGGTG-1_Jeff1.bam                   3                   3
# 3  AAACCTGTCCTGACAA-1_Jeff1.bam                   5                   5
# 4  AAACGGGAGCTAGGCA-1_Jeff1.bam                   3                   3
#
#    chr1:925000-950000  chr1:950000-975000  chr1:975000-1000000  \
# 0                   3                   3                    3
# 1                   3                   3                    3
# 2                   3                   3                    3
# 3                   5                   5                    5
# 4                   3                   3                    3
#
#    chr1:1000000-1025000  chr1:1025000-1050000  chr1:1050000-1075000  \
# 0                     3                     3                     3
# 1                     3                     3                     3
# 2                     3                     3                     3
# 3                     5                     5                     5
# 4                     3                     3                     3
#
#    chr1:1075000-1100000  ...  chr4:189925000-189950000  \
# 0                     3  ...                       NaN
# 1                     3  ...                       NaN
# 2                     3  ...                       NaN
# 3                     5  ...                       NaN
# 4                     3  ...                       NaN
#
#    chr4:189950000-189975000  chr4:189975000-190000000  chr5:25000-50000  \
# 0                       NaN                       NaN               NaN
# 1                       NaN                       NaN               NaN
# 2                       NaN                       NaN               NaN
# 3                       NaN                       NaN               NaN
# 4                       NaN                       NaN               NaN
#
#    chr13:18725000-18750000  chr18:50000-75000  chr18:75000-100000  \
# 0                      NaN                NaN                 NaN
# 1                      NaN                NaN                 NaN
# 2                      NaN                NaN                 NaN
# 3                      NaN                NaN                 NaN
# 4                      NaN                NaN                 NaN
#
#    chr18:100000-125000  chr18:125000-150000  chr22:16025000-16050000
# 0                  NaN                  NaN                      NaN
# 1                  NaN                  NaN                      NaN
# 2                  NaN                  NaN                      NaN
# 3                  NaN                  NaN                      NaN
# 4                  NaN                  NaN                      NaN
#
# [5 rows x 111563 columns]

# %%
# remove columns with >1% NaNs
perc = 1.0
min_count =  int(((100-perc)/100)*CNV_df.shape[0] + 1)
CNV_df = CNV_df.dropna( axis=1, 
                thresh=min_count)
CNV_df
# Out:
#                                Cell  chr1:875000-900000  chr1:900000-925000  \
# 0      AAACCTGAGGAGCGTT-1_Jeff1.bam                   3                   3
# 1      AAACCTGCAGTTTGCA-1_Jeff1.bam                   3                   3
# 2      AAACCTGGTCTCGGTG-1_Jeff1.bam                   3                   3
# 3      AAACCTGTCCTGACAA-1_Jeff1.bam                   5                   5
# 4      AAACGGGAGCTAGGCA-1_Jeff1.bam                   3                   3
# ...                             ...                 ...                 ...
# 11712        GSM2904963_delDupl.bam                   2                   2
# 11713        GSM2904964_delDupl.bam                   2                   3
# 11714        GSM2904965_delDupl.bam                   2                   2
# 11715        GSM2904966_delDupl.bam                   2                   2
# 11716        GSM2904967_delDupl.bam                   2                   2
#
#        chr1:925000-950000  chr1:950000-975000  chr1:975000-1000000  \
# 0                       3                   3                    3
# 1                       3                   3                    3
# 2                       3                   3                    3
# 3                       5                   5                    5
# 4                       3                   3                    3
# ...                   ...                 ...                  ...
# 11712                   2                   2                    2
# 11713                   3                   3                    3
# 11714                   2                   2                    2
# 11715                   2                   2                    2
# 11716                   2                   2                    2
#
#        chr1:1000000-1025000  chr1:1025000-1050000  chr1:1050000-1075000  \
# 0                         3                     3                     3
# 1                         3                     3                     3
# 2                         3                     3                     3
# 3                         5                     5                     5
# 4                         3                     3                     3
# ...                     ...                   ...                   ...
# 11712                     2                     2                     2
# 11713                     3                     3                     3
# 11714                     2                     2                     2
# 11715                     2                     2                     2
# 11716                     2                     2                     2
#
#        chr1:1075000-1100000  ...  chr22:50475000-50500000  \
# 0                         3  ...                        2
# 1                         3  ...                        2
# 2                         3  ...                        2
# 3                         5  ...                        3
# 4                         3  ...                        2
# ...                     ...  ...                      ...
# 11712                     2  ...                        3
# 11713                     3  ...                        3
# 11714                     2  ...                        3
# 11715                     2  ...                        3
# 11716                     2  ...                        3
#
#        chr22:50500000-50525000  chr22:50525000-50550000  \
# 0                            2                        2
# 1                            2                        2
# 2                            2                        2
# 3                            3                        3
# 4                            2                        2
# ...                        ...                      ...
# 11712                        3                        3
# 11713                        3                        3
# 11714                        3                        3
# 11715                        3                        3
# 11716                        3                        3
#
#        chr22:50550000-50575000  chr22:50575000-50600000  \
# 0                            2                        2
# 1                            2                        2
# 2                            2                        2
# 3                            3                        3
# 4                            2                        2
# ...                        ...                      ...
# 11712                        3                        3
# 11713                        3                        3
# 11714                        3                        3
# 11715                        3                        3
# 11716                        3                        3
#
#        chr22:50600000-50625000  chr22:50625000-50650000  \
# 0                            2                        2
# 1                            2                        2
# 2                            2                        2
# 3                            3                        3
# 4                            2                        2
# ...                        ...                      ...
# 11712                        3                        3
# 11713                        3                        3
# 11714                        3                        3
# 11715                        3                        3
# 11716                        3                        3
#
#        chr22:50650000-50675000  chr22:50675000-50700000  \
# 0                            2                        2
# 1                            2                        2
# 2                            2                        2
# 3                            3                        3
# 4                            2                        2
# ...                        ...                      ...
# 11712                        3                        3
# 11713                        3                        3
# 11714                        3                        3
# 11715                        3                        3
# 11716                        3                        3
#
#        chr22:50700000-50725000
# 0                            2
# 1                            2
# 2                            2
# 3                            3
# 4                            2
# ...                        ...
# 11712                        3
# 11713                        3
# 11714                        3
# 11715                        3
# 11716                        3
#
# [11717 rows x 111502 columns]

# %%
#get metadata
metadata_df  = pd.read_csv ('KRONOS_MK_DU_CONNOLLY_TAKAHASHI_Cell_Types_Rep_Phase_v2.csv.gz', sep=',')
metadata_df.head()
# Out:
#                                Cell  Type            Rep Phase
# 0      AAACCTGAGATACACA-1_Hela1.bam  JEFF         JEFF_1     S
# 1      AAACCTGAGGAGCGTT-1_Jeff1.bam  HeLa         HeLa_1     S
# 2      AAACCTGAGTAGATCA-1_Hela1.bam  JEFF         JEFF_1     S
# 3      AAACCTGCAAACTCAC-1_Hela1.bam  JEFF         JEFF_1     S
# 4  AAACCTGCAACCCAAT-1_First_exp.bam  MCF7  MCF7_Unsorted    G1

# %%
all_data  = pd.merge(metadata_df, CNV_df, left_on='Cell', right_on='Cell', how='inner')
all_data.head(20)
# Out:
#                                 Cell  Type            Rep Phase  \
# 0       AAACCTGAGATACACA-1_Hela1.bam  JEFF         JEFF_1     S
# 1       AAACCTGAGGAGCGTT-1_Jeff1.bam  HeLa         HeLa_1     S
# 2       AAACCTGAGTAGATCA-1_Hela1.bam  JEFF         JEFF_1     S
# 3       AAACCTGCAAACTCAC-1_Hela1.bam  JEFF         JEFF_1     S
# 4   AAACCTGCAACCCAAT-1_First_exp.bam  MCF7  MCF7_Unsorted    G1
# 5       AAACCTGCAGTTTGCA-1_Jeff1.bam  HeLa         HeLa_1    G1
# 6      AAACCTGCATTGAAGA-1_Normal.bam  MCF7           MCF7     S
# 7      AAACCTGGTCATTACG-1_Normal.bam  MCF7           MCF7     S
# 8      AAACCTGGTCCGAAGA-1_Normal.bam  MCF7           MCF7     S
# 9       AAACCTGGTCCTCGGA-1_Hela2.bam  JEFF         JEFF_2     S
# 10      AAACCTGGTCTCGGTG-1_Jeff1.bam  HeLa         HeLa_1    G1
# 11      AAACCTGGTTAAGTAG-1_Hela2.bam  JEFF         JEFF_2     S
# 12      AAACCTGGTTGCCACG-1_Hela2.bam  JEFF         JEFF_2     S
# 13      AAACCTGTCATCGCAA-1_Hela1.bam  JEFF         JEFF_1     S
# 14      AAACCTGTCCGATACA-1_Hela2.bam  JEFF         JEFF_2     S
# 15      AAACCTGTCCTGACAA-1_Jeff1.bam  HeLa         HeLa_1     S
# 16      AAACGGGAGTCAAGGC-1_Hela1.bam  JEFF         JEFF_1     S
# 17      AAACGGGAGTGATGAT-1_Jeff1.bam  HeLa         HeLa_1     S
# 18      AAACGGGCACGTGGCT-1_Hela1.bam  JEFF         JEFF_1    G1
# 19      AAACGGGGTATAAGTG-1_Hela2.bam  JEFF         JEFF_2     S
#
#     chr1:875000-900000  chr1:900000-925000  chr1:925000-950000  \
# 0                    2                   2                   2
# 1                    3                   3                   3
# 2                    2                   2                   2
# 3                    2                   2                   2
# 4                    3                   3                   3
# 5                    3                   3                   3
# 6                    5                   5                   5
# 7                    2                   2                   2
# 8                    4                   4                   4
# 9                    2                   2                   2
# 10                   3                   3                   3
# 11                   2                   2                   2
# 12                   3                   3                   3
# 13                   1                   1                   1
# 14                   2                   2                   2
# 15                   5                   5                   5
# 16                   1                   1                   1
# 17                   3                   3                   3
# 18                   2                   2                   2
# 19                   3                   3                   3
#
#     chr1:950000-975000  chr1:975000-1000000  chr1:1000000-1025000  ...  \
# 0                    2                    2                     2  ...
# 1                    3                    3                     3  ...
# 2                    2                    2                     2  ...
# 3                    2                    2                     2  ...
# 4                    3                    3                     3  ...
# 5                    3                    3                     3  ...
# 6                    5                    5                     5  ...
# 7                    2                    2                     2  ...
# 8                    4                    4                     4  ...
# 9                    2                    2                     2  ...
# 10                   3                    3                     3  ...
# 11                   2                    2                     2  ...
# 12                   3                    3                     3  ...
# 13                   1                    1                     1  ...
# 14                   2                    2                     2  ...
# 15                   5                    5                     5  ...
# 16                   1                    1                     1  ...
# 17                   3                    3                     3  ...
# 18                   2                    2                     2  ...
# 19                   3                    3                     3  ...
#
#     chr22:50475000-50500000  chr22:50500000-50525000  chr22:50525000-50550000  \
# 0                         2                        2                        2
# 1                         2                        2                        2
# 2                         2                        2                        2
# 3                         2                        2                        2
# 4                         2                        2                        2
# 5                         2                        2                        2
# 6                         3                        3                        3
# 7                         3                        3                        3
# 8                         3                        3                        3
# 9                         2                        2                        2
# 10                        2                        2                        2
# 11                        2                        2                        2
# 12                        3                        3                        3
# 13                        2                        2                        2
# 14                        2                        2                        2
# 15                        3                        3                        3
# 16                        2                        2                        2
# 17                        2                        2                        2
# 18                        2                        2                        2
# 19                        3                        3                        3
#
#     chr22:50550000-50575000  chr22:50575000-50600000  chr22:50600000-50625000  \
# 0                         2                        2                        2
# 1                         2                        2                        2
# 2                         2                        2                        2
# 3                         2                        2                        2
# 4                         2                        2                        2
# 5                         2                        2                        2
# 6                         3                        3                        3
# 7                         3                        3                        3
# 8                         3                        3                        3
# 9                         2                        2                        2
# 10                        2                        2                        2
# 11                        2                        2                        2
# 12                        3                        3                        3
# 13                        2                        2                        2
# 14                        2                        2                        2
# 15                        3                        3                        3
# 16                        2                        2                        2
# 17                        2                        2                        2
# 18                        2                        2                        2
# 19                        3                        3                        3
#
#     chr22:50625000-50650000  chr22:50650000-50675000  chr22:50675000-50700000  \
# 0                         2                        2                        2
# 1                         2                        2                        2
# 2                         2                        2                        2
# 3                         2                        2                        2
# 4                         2                        2                        2
# 5                         2                        2                        2
# 6                         3                        3                        3
# 7                         3                        3                        3
# 8                         3                        3                        3
# 9                         2                        2                        2
# 10                        2                        2                        2
# 11                        2                        2                        2
# 12                        3                        3                        3
# 13                        2                        2                        2
# 14                        2                        2                        2
# 15                        3                        3                        3
# 16                        2                        2                        2
# 17                        2                        2                        2
# 18                        2                        2                        2
# 19                        3                        3                        3
#
#     chr22:50700000-50725000
# 0                         2
# 1                         2
# 2                         2
# 3                         2
# 4                         2
# 5                         2
# 6                         3
# 7                         3
# 8                         3
# 9                         2
# 10                        2
# 11                        2
# 12                        3
# 13                        2
# 14                        2
# 15                        3
# 16                        2
# 17                        2
# 18                        2
# 19                        3
#
# [20 rows x 111505 columns]

# %%
all_data.Type.value_counts()
# Out:
# GM12878        2848
# MCF7           2144
# JEFF           1130
# HeLa            523
# HCT116          483
# HCT116_DKO1     378
# hTERT-RPE1       17
# Name: Type, dtype: int64

# %%
all_data.Phase.value_counts()
# Out:
# S     5250
# G1    2273
# Name: Phase, dtype: int64

# %%
all_data[['Type','Phase']].value_counts(sort=False)
# Out:
# Type         Phase
# GM12878      G1       1193
#              S        1655
# HCT116       G1         49
#              S         434
# HCT116_DKO1  G1         40
#              S         338
# HeLa         G1        224
#              S         299
# JEFF         G1        132
#              S         998
# MCF7         G1        632
#              S        1512
# hTERT-RPE1   G1          3
#              S          14
# dtype: int64

# %%
all_data[['Type','Rep','Phase']].value_counts(sort=False)
# Out:
# Type         Rep                         Phase
# GM12878      EarlyS_library1_replicate1  S         602
#              G1_library1_replicate1      G1        667
#              G2_library1_replicate1      G1        526
#              LateS_library1_replicate1   S         358
#              S_library1_replicate1       S         695
# HCT116       G1                          G1         49
#              S                           S         434
# HCT116_DKO1  G1                          G1         40
#              S                           S         338
# HeLa         HeLa_1                      G1        120
#                                          S         136
#              HeLa_2                      G1        104
#                                          S         163
# JEFF         JEFF_1                      G1         70
#                                          S         575
#              JEFF_2                      G1         62
#                                          S         423
# MCF7         MCF7                        G1        380
#                                          S        1425
#              MCF7_Unsorted               G1        252
#                                          S          87
# hTERT-RPE1   Paired                      G1          1
#                                          S           3
#              Single                      G1          2
#                                          S          11
# dtype: int64

# %%
metadata = all_data[['Cell','Type','Rep','Phase']]
all_data=all_data.drop(['Rep'], axis=1)

# %%
len(all_data.columns)
# Out:
# 111504

# %%
G = all_data.loc[all_data.Phase == 'G1']
for ctype in np.unique(all_data.Type):
    print(ctype)
    ctype_dta = G.loc[G.Type == ctype]
    print(ctype_dta.median(numeric_only=True).median())
# Out:
# GM12878
# 2.0
# HCT116
# 2.0
# HCT116_DKO1
# 2.0
# HeLa
# 3.0
# JEFF
# 2.0
# MCF7
# 4.0
# hTERT-RPE1
# 2.0

# %%
#training dataset
x = sample(list(all_data.index),int(len(all_data.index)*.80))
x = all_data.drop(x).copy()
#testing
X = all_data.drop(x.index).copy()

# %%
# split into input (X) and output (y) variables
#Training
Y = X[["Phase"]]
Y = Y.Phase.astype("category").cat.codes
X = X.iloc[:,3:]
#Testing
y = x[["Phase"]]
y = y.Phase.astype("category").cat.codes
x = x.iloc[:,3:]

# %%
X #training
# Out:
#       chr1:875000-900000  chr1:900000-925000  chr1:925000-950000  \
# 0                      2                   2                   2
# 1                      3                   3                   3
# 2                      2                   2                   2
# 3                      2                   2                   2
# 4                      3                   3                   3
# ...                  ...                 ...                 ...
# 7518                   2                   2                   2
# 7519                   2                   3                   3
# 7520                   2                   2                   2
# 7521                   2                   2                   2
# 7522                   2                   2                   2
#
#       chr1:950000-975000  chr1:975000-1000000  chr1:1000000-1025000  \
# 0                      2                    2                     2
# 1                      3                    3                     3
# 2                      2                    2                     2
# 3                      2                    2                     2
# 4                      3                    3                     3
# ...                  ...                  ...                   ...
# 7518                   2                    2                     2
# 7519                   3                    3                     3
# 7520                   2                    2                     2
# 7521                   2                    2                     2
# 7522                   2                    2                     2
#
#       chr1:1025000-1050000  chr1:1050000-1075000  chr1:1075000-1100000  \
# 0                        2                     2                     2
# 1                        3                     3                     3
# 2                        2                     2                     2
# 3                        2                     2                     2
# 4                        3                     3                     3
# ...                    ...                   ...                   ...
# 7518                     2                     2                     2
# 7519                     3                     3                     3
# 7520                     2                     2                     2
# 7521                     2                     2                     2
# 7522                     2                     2                     2
#
#       chr1:1100000-1125000  ...  chr22:50475000-50500000  \
# 0                        2  ...                        2
# 1                        3  ...                        2
# 2                        2  ...                        2
# 3                        2  ...                        2
# 4                        3  ...                        2
# ...                    ...  ...                      ...
# 7518                     2  ...                        3
# 7519                     3  ...                        3
# 7520                     2  ...                        3
# 7521                     2  ...                        3
# 7522                     2  ...                        3
#
#       chr22:50500000-50525000  chr22:50525000-50550000  \
# 0                           2                        2
# 1                           2                        2
# 2                           2                        2
# 3                           2                        2
# 4                           2                        2
# ...                       ...                      ...
# 7518                        3                        3
# 7519                        3                        3
# 7520                        3                        3
# 7521                        3                        3
# 7522                        3                        3
#
#       chr22:50550000-50575000  chr22:50575000-50600000  \
# 0                           2                        2
# 1                           2                        2
# 2                           2                        2
# 3                           2                        2
# 4                           2                        2
# ...                       ...                      ...
# 7518                        3                        3
# 7519                        3                        3
# 7520                        3                        3
# 7521                        3                        3
# 7522                        3                        3
#
#       chr22:50600000-50625000  chr22:50625000-50650000  \
# 0                           2                        2
# 1                           2                        2
# 2                           2                        2
# 3                           2                        2
# 4                           2                        2
# ...                       ...                      ...
# 7518                        3                        3
# 7519                        3                        3
# 7520                        3                        3
# 7521                        3                        3
# 7522                        3                        3
#
#       chr22:50650000-50675000  chr22:50675000-50700000  \
# 0                           2                        2
# 1                           2                        2
# 2                           2                        2
# 3                           2                        2
# 4                           2                        2
# ...                       ...                      ...
# 7518                        3                        3
# 7519                        3                        3
# 7520                        3                        3
# 7521                        3                        3
# 7522                        3                        3
#
#       chr22:50700000-50725000
# 0                           2
# 1                           2
# 2                           2
# 3                           2
# 4                           2
# ...                       ...
# 7518                        3
# 7519                        3
# 7520                        3
# 7521                        3
# 7522                        3
#
# [6018 rows x 111501 columns]

# %%
x #testing
# Out:
#       chr1:875000-900000  chr1:900000-925000  chr1:925000-950000  \
# 8                      4                   4                   4
# 9                      2                   2                   2
# 16                     1                   1                   1
# 19                     3                   3                   3
# 38                     2                   2                   2
# ...                  ...                 ...                 ...
# 7497                   1                   1                   1
# 7501                   1                   1                   1
# 7505                   2                   2                   1
# 7509                   2                   2                   2
# 7513                   2                   3                   3
#
#       chr1:950000-975000  chr1:975000-1000000  chr1:1000000-1025000  \
# 8                      4                    4                     4
# 9                      2                    2                     2
# 16                     1                    1                     1
# 19                     3                    3                     3
# 38                     2                    2                     2
# ...                  ...                  ...                   ...
# 7497                   1                    1                     1
# 7501                   1                    1                     1
# 7505                   1                    1                     1
# 7509                   2                    2                     2
# 7513                   3                    3                     3
#
#       chr1:1025000-1050000  chr1:1050000-1075000  chr1:1075000-1100000  \
# 8                        4                     4                     4
# 9                        2                     2                     2
# 16                       1                     1                     1
# 19                       3                     3                     3
# 38                       2                     2                     2
# ...                    ...                   ...                   ...
# 7497                     1                     1                     1
# 7501                     1                     1                     1
# 7505                     1                     1                     1
# 7509                     2                     2                     2
# 7513                     3                     3                     3
#
#       chr1:1100000-1125000  ...  chr22:50475000-50500000  \
# 8                        4  ...                        3
# 9                        2  ...                        2
# 16                       1  ...                        2
# 19                       3  ...                        3
# 38                       2  ...                        2
# ...                    ...  ...                      ...
# 7497                     1  ...                        1
# 7501                     1  ...                        2
# 7505                     1  ...                        2
# 7509                     2  ...                        3
# 7513                     3  ...                        3
#
#       chr22:50500000-50525000  chr22:50525000-50550000  \
# 8                           3                        3
# 9                           2                        2
# 16                          2                        2
# 19                          3                        3
# 38                          2                        2
# ...                       ...                      ...
# 7497                        1                        1
# 7501                        2                        2
# 7505                        2                        2
# 7509                        3                        3
# 7513                        3                        3
#
#       chr22:50550000-50575000  chr22:50575000-50600000  \
# 8                           3                        3
# 9                           2                        2
# 16                          2                        2
# 19                          3                        3
# 38                          2                        2
# ...                       ...                      ...
# 7497                        1                        1
# 7501                        2                        2
# 7505                        2                        2
# 7509                        3                        3
# 7513                        3                        3
#
#       chr22:50600000-50625000  chr22:50625000-50650000  \
# 8                           3                        3
# 9                           2                        2
# 16                          2                        2
# 19                          3                        3
# 38                          2                        2
# ...                       ...                      ...
# 7497                        1                        1
# 7501                        2                        2
# 7505                        2                        2
# 7509                        3                        3
# 7513                        3                        3
#
#       chr22:50650000-50675000  chr22:50675000-50700000  \
# 8                           3                        3
# 9                           2                        2
# 16                          2                        2
# 19                          3                        3
# 38                          2                        2
# ...                       ...                      ...
# 7497                        1                        1
# 7501                        2                        2
# 7505                        2                        2
# 7509                        3                        3
# 7513                        3                        3
#
#       chr22:50700000-50725000
# 8                           3
# 9                           2
# 16                          2
# 19                          3
# 38                          2
# ...                       ...
# 7497                        1
# 7501                        2
# 7505                        2
# 7509                        3
# 7513                        3
#
# [1505 rows x 111501 columns]

# %%
index = np.char.split(list(x.columns), sep =':')
index = np.delete(list(index), 1, 1)
index = [item for sublist in index for item in sublist]
np.unique(index)
# Out:
# array(['chr1', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15',
#        'chr16', 'chr17', 'chr18', 'chr19', 'chr2', 'chr20', 'chr21',
#        'chr22', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9'],
#       dtype='<U5')

# %%
y
# Out:
# 8       1
# 9       1
# 16      1
# 19      1
# 38      1
#        ..
# 7497    1
# 7501    1
# 7505    1
# 7509    1
# 7513    1
# Length: 1505, dtype: int8

# %%
regions = len(x.columns)
cells = len(x.index)
print(regions, cells)
# Out:
# 111501 1505

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# from sklearn.model_selection import train_test_split
# Define the data augmentation functions

def add_random_noise(dataframe, noise_factor):
    noisy_dataframe = dataframe.copy()  # Create a copy of the original dataframe
    num_columns = dataframe.shape[1]  # Number of columns in the dataframe

    for i, row in noisy_dataframe.iterrows():
        noise_percentage = np.random.uniform(0.05, 0.75)
        # Select a random subset of columns to add noise
        num_columns_noise = int(noise_percentage * num_columns)
        columns_noise = np.random.choice(dataframe.columns, num_columns_noise, replace=False)
        # Add random noise to the selected columns of the row
        noise = np.random.normal(loc=0, scale=noise_factor, size=num_columns_noise)
        row[columns_noise] += noise

    return noisy_dataframe

X_train, Y_train = X.copy(), Y.copy()

# Add random noise
noise_factor = 1  # Adjust the noise factor according to your preference
X_train_augmented = add_random_noise(X_train.sample(int(len(X_train)/2)).copy(), noise_factor)


# Concatenate the augmented data with the original training data
Y_train_augmented = pd.concat([Y_train, Y_train.loc[X_train_augmented.index.tolist()]], ignore_index=True)
X_train_augmented = pd.concat([X_train, X_train_augmented], ignore_index=True).round(0).abs()

# %%
X_train_augmented
# Out:
#       chr1:875000-900000  chr1:900000-925000  chr1:925000-950000  \
# 0                      2                   2                   2
# 1                      3                   3                   3
# 2                      2                   2                   2
# 3                      2                   2                   2
# 4                      3                   3                   3
# ...                  ...                 ...                 ...
# 9022                   4                   4                   4
# 9023                   3                   3                   3
# 9024                   2                   2                   2
# 9025                   3                   3                   3
# 9026                   3                   3                   3
#
#       chr1:950000-975000  chr1:975000-1000000  chr1:1000000-1025000  \
# 0                      2                    2                     2
# 1                      3                    3                     3
# 2                      2                    2                     2
# 3                      2                    2                     2
# 4                      3                    3                     3
# ...                  ...                  ...                   ...
# 9022                   4                    4                     4
# 9023                   3                    3                     3
# 9024                   2                    2                     2
# 9025                   3                    3                     3
# 9026                   3                    3                     3
#
#       chr1:1025000-1050000  chr1:1050000-1075000  chr1:1075000-1100000  \
# 0                        2                     2                     2
# 1                        3                     3                     3
# 2                        2                     2                     2
# 3                        2                     2                     2
# 4                        3                     3                     3
# ...                    ...                   ...                   ...
# 9022                     4                     4                     4
# 9023                     3                     3                     3
# 9024                     2                     2                     2
# 9025                     3                     3                     3
# 9026                     3                     3                     3
#
#       chr1:1100000-1125000  ...  chr22:50475000-50500000  \
# 0                        2  ...                        2
# 1                        3  ...                        2
# 2                        2  ...                        2
# 3                        2  ...                        2
# 4                        3  ...                        2
# ...                    ...  ...                      ...
# 9022                     4  ...                        4
# 9023                     3  ...                        2
# 9024                     2  ...                        3
# 9025                     3  ...                        3
# 9026                     3  ...                        2
#
#       chr22:50500000-50525000  chr22:50525000-50550000  \
# 0                           2                        2
# 1                           2                        2
# 2                           2                        2
# 3                           2                        2
# 4                           2                        2
# ...                       ...                      ...
# 9022                        4                        4
# 9023                        2                        2
# 9024                        3                        3
# 9025                        3                        3
# 9026                        2                        2
#
#       chr22:50550000-50575000  chr22:50575000-50600000  \
# 0                           2                        2
# 1                           2                        2
# 2                           2                        2
# 3                           2                        2
# 4                           2                        2
# ...                       ...                      ...
# 9022                        4                        4
# 9023                        2                        2
# 9024                        3                        3
# 9025                        3                        3
# 9026                        2                        2
#
#       chr22:50600000-50625000  chr22:50625000-50650000  \
# 0                           2                        2
# 1                           2                        2
# 2                           2                        2
# 3                           2                        2
# 4                           2                        2
# ...                       ...                      ...
# 9022                        4                        4
# 9023                        2                        2
# 9024                        3                        3
# 9025                        3                        3
# 9026                        2                        2
#
#       chr22:50650000-50675000  chr22:50675000-50700000  \
# 0                           2                        2
# 1                           2                        2
# 2                           2                        2
# 3                           2                        2
# 4                           2                        2
# ...                       ...                      ...
# 9022                        4                        4
# 9023                        2                        2
# 9024                        3                        3
# 9025                        3                        3
# 9026                        2                        2
#
#       chr22:50700000-50725000
# 0                           2
# 1                           2
# 2                           2
# 3                           2
# 4                           2
# ...                       ...
# 9022                        4
# 9023                        2
# 9024                        3
# 9025                        3
# 9026                        2
#
# [9027 rows x 111501 columns]

# %%
# Create a sequential model
model = Sequential()
# Add layers to the model
model.add(Dense(64, activation='relu', input_shape=(regions,)))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping
import random
# fit the model on the train dataset
callback = EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True)
history = model.fit(X_train_augmented.astype(int).copy(), Y_train_augmented.copy(), batch_size=32, epochs=100, validation_data=(x.copy(), y.copy()),
                   use_multiprocessing=True, workers=6, callbacks=[callback])
# Out:
# Epoch 1/100
# 283/283 [==============================] - 25s 84ms/step - loss: 2.6598 - accuracy: 0.8812 - val_loss: 0.1573 - val_accuracy: 0.9575
# Epoch 2/100
# 283/283 [==============================] - 15s 52ms/step - loss: 0.8972 - accuracy: 0.9055 - val_loss: 0.1716 - val_accuracy: 0.9728
# Epoch 3/100
# 283/283 [==============================] - 15s 51ms/step - loss: 0.3557 - accuracy: 0.9431 - val_loss: 1.3339 - val_accuracy: 0.8578
# Epoch 4/100
# 283/283 [==============================] - 15s 51ms/step - loss: 0.5546 - accuracy: 0.9241 - val_loss: 0.1393 - val_accuracy: 0.9734
# Epoch 5/100
# 283/283 [==============================] - 15s 51ms/step - loss: 0.2031 - accuracy: 0.9649 - val_loss: 0.1926 - val_accuracy: 0.9575
# Epoch 6/100
# 283/283 [==============================] - 15s 52ms/step - loss: 0.3170 - accuracy: 0.9431 - val_loss: 0.6479 - val_accuracy: 0.9056
# Epoch 7/100
# 283/283 [==============================] - 15s 52ms/step - loss: 1.5350 - accuracy: 0.9112 - val_loss: 0.2117 - val_accuracy: 0.9422
# Epoch 8/100
# 283/283 [==============================] - 14s 51ms/step - loss: 0.1806 - accuracy: 0.9648 - val_loss: 0.1647 - val_accuracy: 0.9654
# Epoch 9/100
# 283/283 [==============================] - 16s 57ms/step - loss: 0.1217 - accuracy: 0.9709 - val_loss: 0.0885 - val_accuracy: 0.9741
# Epoch 10/100
# 283/283 [==============================] - 15s 54ms/step - loss: 0.1274 - accuracy: 0.9646 - val_loss: 0.1033 - val_accuracy: 0.9681
# Epoch 11/100
# 283/283 [==============================] - 15s 54ms/step - loss: 0.1074 - accuracy: 0.9681 - val_loss: 0.0619 - val_accuracy: 0.9794
# Epoch 12/100
# 283/283 [==============================] - 15s 54ms/step - loss: 0.0884 - accuracy: 0.9742 - val_loss: 0.0580 - val_accuracy: 0.9781
# Epoch 13/100
# 283/283 [==============================] - 15s 54ms/step - loss: 0.0680 - accuracy: 0.9783 - val_loss: 0.0731 - val_accuracy: 0.9754
# Epoch 14/100
# 283/283 [==============================] - 15s 53ms/step - loss: 0.3897 - accuracy: 0.9091 - val_loss: 0.3181 - val_accuracy: 0.6990
# Epoch 15/100
# 283/283 [==============================] - 15s 53ms/step - loss: 0.2367 - accuracy: 0.8982 - val_loss: 0.1966 - val_accuracy: 0.9728
# Epoch 16/100
# 283/283 [==============================] - 15s 52ms/step - loss: 0.1852 - accuracy: 0.9710 - val_loss: 0.1660 - val_accuracy: 0.9694
# Epoch 17/100
# 283/283 [==============================] - 15s 53ms/step - loss: 0.1583 - accuracy: 0.9723 - val_loss: 0.1557 - val_accuracy: 0.9674
# Epoch 18/100
# 283/283 [==============================] - 15s 52ms/step - loss: 0.1442 - accuracy: 0.9699 - val_loss: 0.1309 - val_accuracy: 0.9734
# Epoch 19/100
# 283/283 [==============================] - 15s 52ms/step - loss: 0.1306 - accuracy: 0.9719 - val_loss: 0.1187 - val_accuracy: 0.9754
# Epoch 20/100
# 283/283 [==============================] - 15s 52ms/step - loss: 0.1312 - accuracy: 0.9655 - val_loss: 0.1163 - val_accuracy: 0.9701
# Epoch 21/100
# 283/283 [==============================] - 15s 54ms/step - loss: 0.1227 - accuracy: 0.9671 - val_loss: 0.1154 - val_accuracy: 0.9688
# Epoch 22/100
# 283/283 [==============================] - 15s 53ms/step - loss: 0.1165 - accuracy: 0.9675 - val_loss: 0.0957 - val_accuracy: 0.9754
# Epoch 23/100
# 283/283 [==============================] - 15s 54ms/step - loss: 0.1175 - accuracy: 0.9663 - val_loss: 0.1244 - val_accuracy: 0.9601
# Epoch 24/100
# 283/283 [==============================] - 15s 52ms/step - loss: 0.8184 - accuracy: 0.5535 - val_loss: 1.1233 - val_accuracy: 0.3010
# Epoch 25/100
# 283/283 [==============================] - 15s 52ms/step - loss: 1.0106 - accuracy: 0.2994 - val_loss: 0.9176 - val_accuracy: 0.3010
# Epoch 26/100
# 283/283 [==============================] - 15s 52ms/step - loss: 0.8573 - accuracy: 0.2994 - val_loss: 0.8037 - val_accuracy: 0.3010

# %%
# evaluate the keras model on testing data
_, accuracy = model.evaluate(x, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0619 - accuracy: 0.9794
# Accuracy: 97.94

# %%
# evaluate the keras model on training data
_, accuracy = model.evaluate(X, Y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 189/189 [==============================] - 4s 20ms/step - loss: 0.0694 - accuracy: 0.9814
# Accuracy: 98.14

# %%
# evaluate the keras model on augmented training data
_, accuracy = model.evaluate(X_train_augmented, Y_train_augmented)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 283/283 [==============================] - 7s 25ms/step - loss: 0.0674 - accuracy: 0.9816
# Accuracy: 98.16

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()
plot_metric(history, 'loss')

# %%
# make class predictions with the model
predictions = (model.predict(all_data.iloc[:,3:]) > 0.5).astype(int)
predictions
# Out:
# 236/236 [==============================] - 6s 23ms/step
# array([[1],
#        [1],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
import tensorflow as tf

localhost_save_option = tf.saved_model.SaveOptions(experimental_io_device="/job:localhost")
model.save('../../MnM/data/25kbModel20230809', options=localhost_save_option)

# %%
np.savetxt(fname = '../../MnM/data/Regions_for_phase_deep_learning_25kbModel20230809.txt', X = np.array(all_data.columns[3:]), fmt="%s", encoding='utf-8')
